# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')
data

data.describe()
data.head()
data.describe(include="object")
data.shape
data.isnull().sum()

print("\n\nThe Feature of dataset are as follows")
print("1.sepal length is:",data["sepal_length"].dtype)
print("2.sepal width is:",data["sepal_width"].dtype)
print("3.petal length is:",data["petal_length"].dtype)
print("4.petal width is:",data["petal_width"].dtype)
print("5.species is:",data["species"].dtype)


sns.histplot(data["sepal_length"],kde=True)
sns.histplot(data["sepal_width"],kde=True)
sns.histplot(data["petal_length"],kde=True)
sns.histplot(data["petal_width"],kde=True)
sns.boxplot(data["sepal_length"])
sns.boxplot(data["sepal_width"])
sns.boxplot(data["petal_length"])
sns.boxplot(data["petal_width"])
sns.boxplot(x="sepal_length",y="species",data=data)
sns.boxplot(x='petal_length',y='species',data=data)
sns.boxplot(x='sepal_width',y='species',data=data)
sns.boxplot(x='petal_width',y='species',data=data)
# Out:
# The Feature of dataset are as follows
# 1.sepal length is: float64
# 2.sepal width is: float64
# 3.petal length is: float64
# 4.petal width is: float64
# 5.species is: object
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...
